# %%
#Importing libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import xgboost as xgb
from sklearn.feature_selection import SelectKBest, chi2
from datetime import datetime, timedelta
import random

# %%
# Load the dataset
df  = pd.read_csv("luxottica_eyewear_Master.csv", index_col=None)

# %%
#displaying top 5 rows
df.head()
# Out:
#    Customer ID   Age  Gender State  Store Location Income Level  \
# 0          1.0  62.0  Female    GA  Target Optical         High
# 1          NaN  65.0  Female    MA  Target Optical         High
# 2          3.0  21.0  Female    NV    LensCrafters       Medium
# 3          4.0  28.0    Male    NY    LensCrafters       Medium
# 4          5.0  21.0  Female    MA   Pearle Vision         High
#
#   Date of First Purchase Last Purchase Date  Type of Eyewear         Brand  \
# 0             25-08-2019         15-09-2022   Safety Eyewear         Gucci
# 1             17-01-2020         11-05-2023   Safety Eyewear         Prada
# 2             13-10-2015         05-05-2023  Reading Glasses  Michael Kors
# 3             26-03-2018                NaN  Reading Glasses        Oakley
# 4             11-10-2020         29-06-2021  Reading Glasses        Persol
#
#    ... Customer Segmentation  Complaint History  Product Return Rate  \
# 0  ...              Inactive                5.0                 0.46
# 1  ...            High-value                7.0                 0.72
# 2  ...              Inactive                9.0                 0.55
# 3  ...              Inactive                0.0                 0.12
# 4  ...                   NaN                1.0                 0.59
#
#   Cross-Sell/Upsell Success Rate Purchase Channel Loyalty Lifetime Value  \
# 0                           0.27                      Low     1738.96815
# 1                           0.90                   Medium            NaN
# 2                           0.79                     High     9799.82000
# 3                           0.03                      NaN     7027.47000
# 4                           0.01                   Medium            NaN
#
#    Average Order Value  Feedback Sales Driver Index  \
# 0           233.902744  Positive               0.51
# 1           552.239465  Positive               1.00
# 2           833.200000  Positive               0.74
# 3           727.390000  Positive                NaN
# 4           772.635501  Negative               0.99
#
#   Number of Product Categories Purchased
# 0                                    3.0
# 1                                    2.0
# 2                                    2.0
# 3                                    1.0
# 4                                    2.0
#
# [5 rows x 36 columns]

# %%
#renaming the column name
df.rename(columns={'Cross-Sell/Upsell Success Rate': 'Cross_Sell_or_Upsell_Success_Rate'}, inplace=True)

# %%
#renaming the column name
df.rename(columns={'Return/Exchange History': 'Return_Or_Exchange_History'}, inplace=True)

# %%
#counting the null values of columns
df.isnull().sum()
# Out:
# Customer ID                               5005
# Age                                       5005
# Gender                                    5005
# State                                     5005
# Store Location                            5005
# Income Level                              5005
# Date of First Purchase                    5005
# Last Purchase Date                        5005
# Type of Eyewear                           5005
# Brand                                     5005
# Model                                     5005
# Price                                     5005
# Discount Amount                           5005
# Last Interaction Type                     5005
# Mode of Purchase                          5005
# Return_Or_Exchange_History                5005
# Customer Support Interactions             5005
# Social Media Engagement                   5005
# Referral Source                           5005
# Churn                                     5005
# Customer Satisfaction                     5005
# Product Usage                             5005
# Loyalty Program Participation             5005
# Engagement with Promotions                5005
# Purchase Frequency                        5005
# Subscription Status                       5005
# Customer Segmentation                     5005
# Complaint History                         5005
# Product Return Rate                       5005
# Cross_Sell_or_Upsell_Success_Rate         5005
# Purchase Channel Loyalty                  5005
# Lifetime Value                            5005
# Average Order Value                       5005
# Feedback                                  5005
# Sales Driver Index                        5005
# Number of Product Categories Purchased    5005
# dtype: int64

# %%
#checking datatypes of columns
df.dtypes
# Out:
# Customer ID                               float64
# Age                                       float64
# Gender                                     object
# State                                      object
# Store Location                             object
# Income Level                               object
# Date of First Purchase                     object
# Last Purchase Date                         object
# Type of Eyewear                            object
# Brand                                      object
# Model                                      object
# Price                                     float64
# Discount Amount                           float64
# Last Interaction Type                      object
# Mode of Purchase                           object
# Return_Or_Exchange_History                 object
# Customer Support Interactions             float64
# Social Media Engagement                   float64
# Referral Source                            object
# Churn                                      object
# Customer Satisfaction                     float64
# Product Usage                              object
# Loyalty Program Participation              object
# Engagement with Promotions                 object
# Purchase Frequency                        float64
# Subscription Status                        object
# Customer Segmentation                      object
# Complaint History                         float64
# Product Return Rate                       float64
# Cross_Sell_or_Upsell_Success_Rate         float64
# Purchase Channel Loyalty                   object
# Lifetime Value                            float64
# Average Order Value                       float64
# Feedback                                   object
# Sales Driver Index                        float64
# Number of Product Categories Purchased    float64
# dtype: object

# %%
#droping customer ID column is which is not required
df =df.drop(columns=['Customer ID'])

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'State', 'Store Location', 'Income Level',
#        'Date of First Purchase', 'Last Purchase Date', 'Type of Eyewear',
#        'Brand', 'Model', 'Price', 'Discount Amount', 'Last Interaction Type',
#        'Mode of Purchase', 'Return_Or_Exchange_History',
#        'Customer Support Interactions', 'Social Media Engagement',
#        'Referral Source', 'Churn', 'Customer Satisfaction', 'Product Usage',
#        'Loyalty Program Participation', 'Engagement with Promotions',
#        'Purchase Frequency', 'Subscription Status', 'Customer Segmentation',
#        'Complaint History', 'Product Return Rate',
#        'Cross_Sell_or_Upsell_Success_Rate', 'Purchase Channel Loyalty',
#        'Lifetime Value', 'Average Order Value', 'Feedback',
#        'Sales Driver Index', 'Number of Product Categories Purchased'],
#       dtype='object')

# %%
#rows which have null values
rows_with_nulls = df[df.isnull().any(axis=1)]

# %%
#printing the null values
rows_with_nulls
# Out:
#          Age  Gender State  Store Location Income Level  \
# 0       62.0  Female    GA  Target Optical         High
# 1       65.0  Female    MA  Target Optical         High
# 2       21.0  Female    NV    LensCrafters       Medium
# 3       28.0    Male    NY    LensCrafters       Medium
# 4       21.0  Female    MA   Pearle Vision         High
# ...      ...     ...   ...             ...          ...
# 100102  41.0    Male   NaN   Pearle Vision       Medium
# 100103  56.0  Female    IL    Sunglass Hut          NaN
# 100104  31.0  Female    GA    Sunglass Hut       Medium
# 100105  26.0  Female    WA    Sunglass Hut       Medium
# 100106   NaN    Male    CA  Target Optical       Medium
#
#        Date of First Purchase Last Purchase Date      Type of Eyewear  \
# 0                  25-08-2019         15-09-2022       Safety Eyewear
# 1                  17-01-2020         11-05-2023       Safety Eyewear
# 2                  13-10-2015         05-05-2023      Reading Glasses
# 3                  26-03-2018                NaN      Reading Glasses
# 4                  11-10-2020         29-06-2021      Reading Glasses
# ...                       ...                ...                  ...
# 100102             07-04-2016         15-11-2022       Sports Eyewear
# 100103             14-05-2018         28-04-2022  Eyewear Accessories
# 100104             15-07-2018         12-06-2023              Goggles
# 100105             07-10-2019         19-11-2021                  NaN
# 100106             21-09-2018         25-02-2023                  NaN
#
#                  Brand          Model  ...  Customer Segmentation  \
# 0                Gucci     Gucci 0140  ...               Inactive
# 1                Prada  Double Bridge  ...             High-value
# 2         Michael Kors         MK2056  ...               Inactive
# 3               Oakley            NaN  ...               Inactive
# 4               Persol            718  ...                    NaN
# ...                ...            ...  ...                    ...
# 100102           Prada            NaN  ...                  Loyal
# 100103  Oliver Peoples          OV520  ...             High-value
# 100104           Fendi     Fendi 0153  ...             High-value
# 100105    Michael Kors         MK2062  ...                At-risk
# 100106           Gucci     Gucci 0140  ...                  Loyal
#
#         Complaint History Product Return Rate  \
# 0                     5.0                0.46
# 1                     7.0                0.72
# 2                     9.0                0.55
# 3                     0.0                0.12
# 4                     1.0                0.59
# ...                   ...                 ...
# 100102                7.0                0.81
# 100103                6.0                0.61
# 100104                3.0                0.96
# 100105                6.0                0.54
# 100106                3.0                 NaN
#
#        Cross_Sell_or_Upsell_Success_Rate Purchase Channel Loyalty  \
# 0                                   0.27                      Low
# 1                                   0.90                   Medium
# 2                                   0.79                     High
# 3                                   0.03                      NaN
# 4                                   0.01                   Medium
# ...                                  ...                      ...
# 100102                              0.80                   Medium
# 100103                              0.12                     High
# 100104                              0.84                      Low
# 100105                              0.18                      Low
# 100106                              0.43                   Medium
#
#         Lifetime Value  Average Order Value  Feedback Sales Driver Index  \
# 0          1738.968150           233.902744  Positive               0.51
# 1                  NaN           552.239465  Positive               1.00
# 2          9799.820000           833.200000  Positive               0.74
# 3          7027.470000           727.390000  Positive                NaN
# 4                  NaN           772.635501  Negative               0.99
# ...                ...                  ...       ...                ...
# 100102     9446.040000           255.330000   Neutral               0.10
# 100103    11065.039920           314.938230   Neutral               0.69
# 100104     6468.370000                  NaN   Neutral               0.31
# 100105     2136.218717           685.872736  Positive               0.77
# 100106    10618.669180                  NaN  Positive               0.87
#
#         Number of Product Categories Purchased
# 0                                          3.0
# 1                                          2.0
# 2                                          2.0
# 3                                          1.0
# 4                                          2.0
# ...                                        ...
# 100102                                     2.0
# 100103                                     3.0
# 100104                                     2.0
# 100105                                     3.0
# 100106                                     2.0
#
# [83503 rows x 35 columns]

# %%
#Checking number of coulmns and rows
df.shape
# Out:
# (100107, 35)

# %%
df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# Out:
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '15-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '29-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '24-02-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '30-04-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '22-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '27-04-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '15-09-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '14-09-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '26-08-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '14-01-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '26-01-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '21-11-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '17-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '19-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '16-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '21-06-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '19-01-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '26-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '29-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '13-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '27-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '31-08-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '26-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '23-11-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '18-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '28-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '31-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '14-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '31-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '28-08-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '25-11-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '27-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '25-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '27-11-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '21-03-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '30-10-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '31-07-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '27-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '13-10-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '21-01-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '30-09-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '29-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '14-10-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '16-10-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '21-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '29-01-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '30-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '24-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '15-03-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '22-03-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '27-10-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '30-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '27-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '30-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '22-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '29-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '24-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '27-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '26-04-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '17-12-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '13-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '15-02-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '24-04-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '21-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '27-08-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '19-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '20-03-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '21-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '20-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '22-04-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '20-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '20-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '13-03-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '19-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '27-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '23-01-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '14-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '23-08-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '28-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '18-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '30-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '15-07-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '28-03-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '18-11-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '17-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '16-09-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '28-03-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '29-04-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '24-12-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '21-07-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '26-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '15-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '22-01-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '14-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '13-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '15-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '20-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '29-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '14-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '27-04-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '15-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '15-04-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '19-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '24-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '15-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '23-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '28-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '16-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '30-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '18-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '25-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '13-07-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '14-11-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '24-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '19-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '19-08-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '16-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '15-03-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '22-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '19-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '27-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '22-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '17-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '22-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '22-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '21-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '26-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '30-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '25-08-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '23-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '19-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '19-01-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '29-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '30-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '13-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '29-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '23-02-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '16-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '16-03-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '15-04-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '14-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '13-09-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '26-03-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '21-10-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '30-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '20-07-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '21-04-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '19-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '15-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '29-05-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '20-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '13-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '19-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '17-07-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '31-01-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '23-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '27-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '21-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '18-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '19-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '14-01-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '31-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '24-01-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '17-01-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '25-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '16-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '19-02-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '29-12-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '16-06-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '19-10-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '24-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '30-12-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '30-04-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '20-06-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '15-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '28-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:1: UserWarning: Parsing '24-03-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Last Purchase Date'] = pd.to_datetime(df['Last Purchase Date'])
# ...
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '15-05-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '24-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '14-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '24-09-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '17-08-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '27-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '15-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '14-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '22-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '16-08-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '28-03-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '29-04-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '18-08-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '15-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '21-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '25-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '24-08-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '30-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '21-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '20-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '21-05-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '29-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '23-04-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '24-06-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '27-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '22-06-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '15-12-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '13-09-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '17-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '26-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '16-11-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '21-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '30-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '15-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '17-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '28-07-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '16-06-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '17-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '25-08-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '16-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '27-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '23-01-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '21-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '13-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '18-02-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '28-08-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '20-11-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '18-06-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '29-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '22-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '15-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '19-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '14-01-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '21-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '25-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '21-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])
# C:\Users\AB92922\AppData\Local\Temp\ipykernel_10664\815430468.py:2: UserWarning: Parsing '19-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date of First Purchase'] = pd.to_datetime(df['Date of First Purchase'])

# %%
df.dtypes
# Out:
# Age                                              float64
# Gender                                            object
# State                                             object
# Store Location                                    object
# Income Level                                      object
# Date of First Purchase                    datetime64[ns]
# Last Purchase Date                        datetime64[ns]
# Type of Eyewear                                   object
# Brand                                             object
# Model                                             object
# Price                                            float64
# Discount Amount                                  float64
# Last Interaction Type                             object
# Mode of Purchase                                  object
# Return_Or_Exchange_History                        object
# Customer Support Interactions                    float64
# Social Media Engagement                          float64
# Referral Source                                   object
# Churn                                             object
# Customer Satisfaction                            float64
# Product Usage                                     object
# Loyalty Program Participation                     object
# Engagement with Promotions                        object
# Purchase Frequency                               float64
# Subscription Status                               object
# Customer Segmentation                             object
# Complaint History                                float64
# Product Return Rate                              float64
# Cross_Sell_or_Upsell_Success_Rate                float64
# Purchase Channel Loyalty                          object
# Lifetime Value                                   float64
# Average Order Value                              float64
# Feedback                                          object
# Sales Driver Index                               float64
# Number of Product Categories Purchased           float64
# dtype: object

# %%
# Replace spaces with underscores in column names
df.columns = df.columns.str.replace(' ', '_')

# Check the updated column names
print("Updated Column Names:", df.columns)
# Out:
# Updated Column Names: Index(['Age', 'Gender', 'State', 'Store_Location', 'Income_Level',
#        'Date_of_First_Purchase', 'Last_Purchase_Date', 'Type_of_Eyewear',
#        'Brand', 'Model', 'Price', 'Discount_Amount', 'Last_Interaction_Type',
#        'Mode_of_Purchase', 'Return_Or_Exchange_History',
#        'Customer_Support_Interactions', 'Social_Media_Engagement',
#        'Referral_Source', 'Churn', 'Customer_Satisfaction', 'Product_Usage',
#        'Loyalty_Program_Participation', 'Engagement_with_Promotions',
#        'Purchase_Frequency', 'Subscription_Status', 'Customer_Segmentation',
#        'Complaint_History', 'Product_Return_Rate',
#        'Cross_Sell_or_Upsell_Success_Rate', 'Purchase_Channel_Loyalty',
#        'Lifetime_Value', 'Average_Order_Value', 'Feedback',
#        'Sales_Driver_Index', 'Number_of_Product_Categories_Purchased'],
#       dtype='object')

# %%
#Exclude rows with missing target values
df = df[df['Churn'].notna()]

# %%
df.shape
# Out:
# (95102, 35)

# %%
import pandas as pd

def QuanQualDates(df):
    quan = []
    qual = []
    dates = []
    
    for columnName in df.columns:
        if df[columnName].dtype == 'O':
            qual.append(columnName)
        elif pd.api.types.is_datetime64_any_dtype(df[columnName]):
            dates.append(columnName)
        else:
            quan.append(columnName)
            
    return quan, qual, dates

# %%
# Apply the function
quantitative, qualitative, dates = QuanQualDates(df)

# %%
print("Quantitative Columns:", quantitative)
# Out:
# Quantitative Columns: ['Age', 'Price', 'Discount_Amount', 'Customer_Support_Interactions', 'Social_Media_Engagement', 'Customer_Satisfaction', 'Purchase_Frequency', 'Complaint_History', 'Product_Return_Rate', 'Cross_Sell_or_Upsell_Success_Rate', 'Lifetime_Value', 'Average_Order_Value', 'Sales_Driver_Index', 'Number_of_Product_Categories_Purchased']

# %%
print("Qualitative Columns:", qualitative)
# Out:
# Qualitative Columns: ['Gender', 'State', 'Store_Location', 'Income_Level', 'Type_of_Eyewear', 'Brand', 'Model', 'Last_Interaction_Type', 'Mode_of_Purchase', 'Return_Or_Exchange_History', 'Referral_Source', 'Churn', 'Product_Usage', 'Loyalty_Program_Participation', 'Engagement_with_Promotions', 'Subscription_Status', 'Customer_Segmentation', 'Purchase_Channel_Loyalty', 'Feedback']

# %%
print("Date Columns:", dates)
# Out:
# Date Columns: ['Date_of_First_Purchase', 'Last_Purchase_Date']

# %%
# Fill missing values for categorical columns with the mode
for quan in quantitative:
    df[quan].fillna(df[quan].mode()[0], inplace=True)

# %%
# Fill missing values for numerical columns with the median
for qual in qualitative:
    df[qual].fillna(df[qual].mode()[0], inplace=True)

# %%
df[dates]
# Out:
#        Date_of_First_Purchase Last_Purchase_Date
# 0                  2019-08-25         2022-09-15
# 2                  2015-10-13         2023-05-05
# 3                  2018-03-26                NaT
# 4                  2020-11-10         2021-06-29
# 5                  2019-11-14         2023-02-24
# ...                       ...                ...
# 100102             2016-07-04         2022-11-15
# 100103             2018-05-14         2022-04-28
# 100104             2018-07-15         2023-12-06
# 100105             2019-07-10         2021-11-19
# 100106             2018-09-21         2023-02-25
#
# [95102 rows x 2 columns]

# %%
df[dates].isnull().sum()
# Out:
# Date_of_First_Purchase    4761
# Last_Purchase_Date        4754
# dtype: int64

# %%
# Verify the changes
print(df.isnull().sum())
# Out:
# Age                                          0
# Gender                                       0
# State                                        0
# Store_Location                               0
# Income_Level                                 0
# Date_of_First_Purchase                    4761
# Last_Purchase_Date                        4754
# Type_of_Eyewear                              0
# Brand                                        0
# Model                                        0
# Price                                        0
# Discount_Amount                              0
# Last_Interaction_Type                        0
# Mode_of_Purchase                             0
# Return_Or_Exchange_History                   0
# Customer_Support_Interactions                0
# Social_Media_Engagement                      0
# Referral_Source                              0
# Churn                                        0
# Customer_Satisfaction                        0
# Product_Usage                                0
# Loyalty_Program_Participation                0
# Engagement_with_Promotions                   0
# Purchase_Frequency                           0
# Subscription_Status                          0
# Customer_Segmentation                        0
# Complaint_History                            0
# Product_Return_Rate                          0
# Cross_Sell_or_Upsell_Success_Rate            0
# Purchase_Channel_Loyalty                     0
# Lifetime_Value                               0
# Average_Order_Value                          0
# Feedback                                     0
# Sales_Driver_Index                           0
# Number_of_Product_Categories_Purchased       0
# dtype: int64

# %%
# Function to generate a random date within a given range
def random_date(start, end):
    return start + timedelta(days=random.randint(0, (end - start).days))

# Generate random dates to fill missing values
num_rows = df.shape[0]

#fill missing 'Date of First date' with random dates between 2015-05-01 and 2020-12-31

df['Date_of_First_Purchase'] = df['Date_of_First_Purchase']. apply(lambda x: random_date(datetime(2015,5,1), datetime(2020, 12, 31)) if pd.isnull(x) else x)

df['Last_Purchase_Date'] = df['Last_Purchase_Date']. apply(lambda x: random_date(datetime(2021,12,1), datetime(2023, 12, 31)) if pd.isnull(x) else x)

# %%
df[dates].isnull().sum()
# Out:
# Date_of_First_Purchase    0
# Last_Purchase_Date        0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Age                                       0
# Gender                                    0
# State                                     0
# Store_Location                            0
# Income_Level                              0
# Date_of_First_Purchase                    0
# Last_Purchase_Date                        0
# Type_of_Eyewear                           0
# Brand                                     0
# Model                                     0
# Price                                     0
# Discount_Amount                           0
# Last_Interaction_Type                     0
# Mode_of_Purchase                          0
# Return_Or_Exchange_History                0
# Customer_Support_Interactions             0
# Social_Media_Engagement                   0
# Referral_Source                           0
# Churn                                     0
# Customer_Satisfaction                     0
# Product_Usage                             0
# Loyalty_Program_Participation             0
# Engagement_with_Promotions                0
# Purchase_Frequency                        0
# Subscription_Status                       0
# Customer_Segmentation                     0
# Complaint_History                         0
# Product_Return_Rate                       0
# Cross_Sell_or_Upsell_Success_Rate         0
# Purchase_Channel_Loyalty                  0
# Lifetime_Value                            0
# Average_Order_Value                       0
# Feedback                                  0
# Sales_Driver_Index                        0
# Number_of_Product_Categories_Purchased    0
# dtype: int64

# %%
#dataframe share after cleaning
df.shape
# Out:
# (95102, 35)

# %%
cleaned_df_updated = df.copy()

# %%
cleaned_df_updated.head(2)
# Out:
#     Age  Gender State  Store_Location Income_Level Date_of_First_Purchase  \
# 0  62.0  Female    GA  Target Optical         High             2019-08-25
# 2  21.0  Female    NV    LensCrafters       Medium             2015-10-13
#
#   Last_Purchase_Date  Type_of_Eyewear         Brand       Model  ...  \
# 0         2022-09-15   Safety Eyewear         Gucci  Gucci 0140  ...
# 2         2023-05-05  Reading Glasses  Michael Kors      MK2056  ...
#
#    Customer_Segmentation  Complaint_History Product_Return_Rate  \
# 0               Inactive                5.0                0.46
# 2               Inactive                9.0                0.55
#
#   Cross_Sell_or_Upsell_Success_Rate Purchase_Channel_Loyalty  Lifetime_Value  \
# 0                              0.27                      Low      1738.96815
# 2                              0.79                     High      9799.82000
#
#    Average_Order_Value  Feedback Sales_Driver_Index  \
# 0           233.902744  Positive               0.51
# 2           833.200000  Positive               0.74
#
#    Number_of_Product_Categories_Purchased
# 0                                     3.0
# 2                                     2.0
#
# [2 rows x 35 columns]

# %%
# Save the  cleaned_df to a CSV file
cleaned_df_updated.to_csv('cleaned_df_luxottica_churn_updated_0108.csv', index=False)
